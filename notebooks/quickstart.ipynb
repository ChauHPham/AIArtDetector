# %% [markdown]
# # Quickstart Notebook
# Train and evaluate the AI Art & Protection detector.

# %%
# !pip -q install -r ../requirements.txt

# %%
import torch, torchvision
from src.train import train
from types import SimpleNamespace

args = SimpleNamespace(
    data_dir='../data',
    checkpoint='../models/detector.pth',
    epochs=1,
    batch_size=8,
    lr=1e-4,
    image_size=224,
    num_classes=3,
    no_pretrain=False
)
# train(args)  # uncomment when data is in place
print('Environment OK. Ready to train once data is added.')
